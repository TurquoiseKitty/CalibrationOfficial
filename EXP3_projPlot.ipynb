# %%
import pandas as pd

Project_df = pd.read_csv("Experiments/EXP3/record_bin/CH_vanillaKernel_proj.csv").set_index("idxes")

CovSelect_df = pd.read_csv("Experiments/EXP3/record_bin/CH_vanillaKernel_covSelect.csv").set_index("idxes")

bench_df = pd.read_csv("Experiments/EXP3/record_bin/muSigma_benchmarks.csv").set_index("idxes")

# %%
import matplotlib.pyplot as plt

x = ["1", "3", "5", "7", "9", "11", "13"]
MACE_ProjDF = Project_df.loc["MACE_Loss"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]]
MACE_ProjDF_std = Project_df.loc["MACE_Loss"][["comp_1_std", "comp_3_std", "comp_5_std", "comp_7_std", "comp_9_std", "comp_11_std", "comp_13_std"]]


MACE_CovSelect = CovSelect_df.loc["MACE_Loss"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]]
MACE_CovSelect_std = CovSelect_df.loc["MACE_Loss"][["comp_1_std", "comp_3_std", "comp_5_std", "comp_7_std", "comp_9_std", "comp_11_std", "comp_13_std"]]



MACE_HNN = bench_df.loc["HNN_MACE_muSigma"][["CaliforniaHousing_mu"]]
MACE_HNN_std = bench_df.loc["HNN_MACE_muSigma"][["CaliforniaHousing_std"]]

MACE_MCDrop = bench_df.loc["MC_drop_MACE_muSigma"][["CaliforniaHousing_mu"]]
MACE_MCDrop_std = bench_df.loc["MC_drop_MACE_muSigma"][["CaliforniaHousing_std"]]

MACE_DeepEns = bench_df.loc["DeepEnsemble_MACE_muSigma"][["CaliforniaHousing_mu"]]
MACE_DeepEns_std = bench_df.loc["DeepEnsemble_MACE_muSigma"][["CaliforniaHousing_std"]]


plt.plot(x, [MACE_HNN]* len(x), label = "MACE_HNN")
plt.plot(x, [MACE_MCDrop]* len(x), label = "MACE_MCDrop")
plt.plot(x, [MACE_DeepEns]* len(x), label = "MACE_DeepEns")
plt.plot(x, MACE_ProjDF, label = "MACE_ProjDF")
plt.plot(x, MACE_CovSelect, label = "MACE_CovSelect")



plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x = ["1", "3", "5", "7", "9", "11", "13"]
AGCE_ProjDF = Project_df.loc["AGCE_Loss"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]]
AGCE_CovSelect = CovSelect_df.loc["AGCE_Loss"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]]
plt.plot(x, AGCE_ProjDF, label = "AGCE_ProjDF")
plt.plot(x, AGCE_CovSelect, label = "AGCE_CovSelect")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x = ["1", "3", "5", "7", "9", "11", "13"]
CheckScore_ProjDF = Project_df.loc["CheckScore"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]]
CheckScore_CovSelect = CovSelect_df.loc["CheckScore"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]]
plt.plot(x, CheckScore_ProjDF, label = "CheckScore_ProjDF")
plt.plot(x, CheckScore_CovSelect, label = "CheckScore_CovSelect")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (15, 5))

# MACE
x = ["1", "3", "5", "7", "9", "11", "13"]
MACE_ProjDF = Project_df.loc["MACE_Loss"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]]
MACE_CovSelect = CovSelect_df.loc["MACE_Loss"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]]
# plt.plot(x, MACE_DE, label = "MACE_DE")


MACE_HNN = bench_df.loc["HNN_MACE_muSigma"][["CaliforniaHousing_mu"]]
MACE_MCDrop = bench_df.loc["MC_drop_MACE_muSigma"][["CaliforniaHousing_mu"]]
MACE_DeepEns = bench_df.loc["DeepEnsemble_MACE_muSigma"][["CaliforniaHousing_mu"]]


ax1.plot(x, [MACE_HNN]* len(x), label = "MACE_HNN")
ax1.plot(x, [MACE_MCDrop]* len(x), label = "MACE_MCDrop")
ax1.plot(x, [MACE_DeepEns]* len(x), label = "MACE_DeepEns")
ax1.plot(x, MACE_ProjDF, label = "MACE_ProjDF")
ax1.plot(x, MACE_CovSelect, label = "MACE_CovSelect")
ax1.set_xlabel("Dimension")
ax1.set_ylabel("Loss")
ax1.legend(loc = 'center right')
ax1.set_title("MACE")


# AGCE
x = ["1", "3", "5", "7", "9", "11", "13"]
AGCE_ProjDF = Project_df.loc["AGCE_Loss"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]]
AGCE_CovSelect = CovSelect_df.loc["AGCE_Loss"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]]


AGCE_HNN = bench_df.loc["HNN_AGCE_muSigma"][["CaliforniaHousing_mu"]]
AGCE_MCDrop = bench_df.loc["MC_drop_AGCE_muSigma"][["CaliforniaHousing_mu"]]
AGCE_DeepEns = bench_df.loc["DeepEnsemble_AGCE_muSigma"][["CaliforniaHousing_mu"]]


ax2.plot(x, [AGCE_HNN]* len(x), label = "AGCE_HNN")
ax2.plot(x, [AGCE_MCDrop]* len(x), label = "AGCE_MCDrop")
ax2.plot(x, [AGCE_DeepEns]* len(x), label = "AGCE_DeepEns")
ax2.plot(x, AGCE_ProjDF, label = "AGCE_ProjDF")
ax2.plot(x, AGCE_CovSelect, label = "AGCE_CovSelect")
ax2.set_xlabel("Dimension")
ax2.set_ylabel("Loss")
ax2.legend(loc = 'center right')
ax2.set_title("AGCE")


# CheckScore
x = ["1", "3", "5", "7", "9", "11", "13"]
CheckScore_ProjDF = Project_df.loc["CheckScore"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]]
CheckScore_CovSelect = CovSelect_df.loc["CheckScore"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]]


CheckScore_HNN = bench_df.loc["HNN_CheckScore_muSigma"][["CaliforniaHousing_mu"]]
CheckScore_MCDrop = bench_df.loc["MC_drop_CheckScore_muSigma"][["CaliforniaHousing_mu"]]
CheckScore_DeepEns = bench_df.loc["DeepEnsemble_CheckScore_muSigma"][["CaliforniaHousing_mu"]]


ax3.plot(x, [CheckScore_HNN]* len(x), label = "CheckScore_HNN")
ax3.plot(x, [CheckScore_MCDrop]* len(x), label = "CheckScore_MCDrop")
ax3.plot(x, [CheckScore_DeepEns]* len(x), label = "CheckScore_DeepEns")
ax3.plot(x, CheckScore_ProjDF, label = "CheckScore_ProjDF")
ax3.plot(x, CheckScore_CovSelect, label = "CheckScore_CovSelect")
ax3.set_xlabel("Dimension")
ax3.set_ylabel("Loss")
ax3.legend(loc = 'center right')
ax3.set_title("CheckScore")
# Out:
# Text(0.5, 1.0, 'CheckScore')

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (15, 4.5))

clrs = sns.color_palette("husl", 5)
# with sns.axes_style("darkgrid"):
    
x = ["1", "3", "5", "7", "9", "11", "13"]

# MACE
MACE_ProjDF = np.array(Project_df.loc["MACE_Loss"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]])
MACE_ProjDF_std = np.array(Project_df.loc["MACE_Loss"][["comp_1_std", "comp_3_std", "comp_5_std", "comp_7_std", "comp_9_std", "comp_11_std", "comp_13_std"]])


MACE_CovSelect = np.array(CovSelect_df.loc["MACE_Loss"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]])
MACE_CovSelect_std = np.array(CovSelect_df.loc["MACE_Loss"][["comp_1_std", "comp_3_std", "comp_5_std", "comp_7_std", "comp_9_std", "comp_11_std", "comp_13_std"]])



MACE_HNN = np.array([bench_df.loc["HNN_MACE_muSigma"][["CaliforniaHousing_mu"]][0]] * len(x))
MACE_HNN_std = np.array([bench_df.loc["HNN_MACE_muSigma"][["CaliforniaHousing_std"]][0]] * len(x))

MACE_MCDrop = np.array([bench_df.loc["MC_drop_MACE_muSigma"][["CaliforniaHousing_mu"]][0]] * len(x))
MACE_MCDrop_std = np.array([bench_df.loc["MC_drop_MACE_muSigma"][["CaliforniaHousing_std"]][0]] * len(x))

MACE_DeepEns = np.array([bench_df.loc["DeepEnsemble_MACE_muSigma"][["CaliforniaHousing_mu"]][0]] * len(x))
MACE_DeepEns_std = np.array([bench_df.loc["DeepEnsemble_MACE_muSigma"][["CaliforniaHousing_std"]][0]] * len(x))



ax1.plot(x, MACE_HNN, "--", label="MACE_HNN", c=clrs[0])
# ax1.fill_between(x, MACE_HNN - MACE_HNN_std,MACE_HNN+MACE_HNN_std ,alpha=0.3, facecolor=clrs[0])

ax1.plot(x, MACE_MCDrop, "--", label="MACE_MCDrop", c=clrs[1])
# ax1.fill_between(x, MACE_MCDrop - MACE_MCDrop_std,MACE_MCDrop+MACE_MCDrop_std ,alpha=0.3, facecolor=clrs[1])

ax1.plot(x, MACE_DeepEns, "--", label="MACE_DeepEns", c=clrs[2])
# ax1.fill_between(x, MACE_DeepEns - MACE_DeepEns_std,MACE_DeepEns+MACE_DeepEns_std ,alpha=0.3, facecolor=clrs[2])

ax1.plot(x, MACE_ProjDF, label="MACE_ProjDF", c=clrs[3])
ax1.fill_between(x, MACE_ProjDF - MACE_ProjDF_std,MACE_ProjDF+MACE_ProjDF_std ,alpha=0.3, facecolor=clrs[3])

ax1.plot(x, MACE_CovSelect, label="MACE_CovSelect", c=clrs[4])
ax1.fill_between(x, MACE_CovSelect - MACE_CovSelect_std,MACE_CovSelect+MACE_CovSelect_std ,alpha=0.3, facecolor=clrs[4])


ax1.set_xlabel("Dimension")
ax1.set_ylabel("Loss")
# ax1.legend(loc = 'center right')
ax1.set_title("MACE")


# AGCE
AGCE_ProjDF = np.array(Project_df.loc["AGCE_Loss"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]])
AGCE_ProjDF_std = np.array(Project_df.loc["AGCE_Loss"][["comp_1_std", "comp_3_std", "comp_5_std", "comp_7_std", "comp_9_std", "comp_11_std", "comp_13_std"]])


AGCE_CovSelect = np.array(CovSelect_df.loc["AGCE_Loss"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]])
AGCE_CovSelect_std = np.array(CovSelect_df.loc["AGCE_Loss"][["comp_1_std", "comp_3_std", "comp_5_std", "comp_7_std", "comp_9_std", "comp_11_std", "comp_13_std"]])



AGCE_HNN = np.array([bench_df.loc["HNN_AGCE_muSigma"][["CaliforniaHousing_mu"]][0]] * len(x))
AGCE_HNN_std = np.array([bench_df.loc["HNN_AGCE_muSigma"][["CaliforniaHousing_std"]][0]] * len(x))

AGCE_MCDrop = np.array([bench_df.loc["MC_drop_AGCE_muSigma"][["CaliforniaHousing_mu"]][0]] * len(x))
AGCE_MCDrop_std = np.array([bench_df.loc["MC_drop_AGCE_muSigma"][["CaliforniaHousing_std"]][0]] * len(x))

AGCE_DeepEns = np.array([bench_df.loc["DeepEnsemble_AGCE_muSigma"][["CaliforniaHousing_mu"]][0]] * len(x))
AGCE_DeepEns_std = np.array([bench_df.loc["DeepEnsemble_AGCE_muSigma"][["CaliforniaHousing_std"]][0]] * len(x))



ax2.plot(x, AGCE_HNN,"--",  label="AGCE_HNN", c=clrs[0])
# ax2.fill_between(x, AGCE_HNN - AGCE_HNN_std,AGCE_HNN+AGCE_HNN_std ,alpha=0.3, facecolor=clrs[0])

ax2.plot(x, AGCE_MCDrop, "--", label="AGCE_MCDrop", c=clrs[1])
# ax2.fill_between(x, AGCE_MCDrop - AGCE_MCDrop_std,AGCE_MCDrop+AGCE_MCDrop_std ,alpha=0.3, facecolor=clrs[1])

ax2.plot(x, AGCE_DeepEns, "--", label="AGCE_DeepEns", c=clrs[2])
# ax2.fill_between(x, AGCE_DeepEns - AGCE_DeepEns_std,AGCE_DeepEns+AGCE_DeepEns_std ,alpha=0.3, facecolor=clrs[2])

ax2.plot(x, AGCE_ProjDF, label="AGCE_ProjDF", c=clrs[3])
ax2.fill_between(x, AGCE_ProjDF - AGCE_ProjDF_std,AGCE_ProjDF+AGCE_ProjDF_std ,alpha=0.3, facecolor=clrs[3])

ax2.plot(x, AGCE_CovSelect, label="AGCE_CovSelect", c=clrs[4])
ax2.fill_between(x, AGCE_CovSelect - AGCE_CovSelect_std,AGCE_CovSelect+AGCE_CovSelect_std ,alpha=0.3, facecolor=clrs[4])


ax2.set_xlabel("Dimension")
ax2.set_ylabel("Loss")
# ax2.legend(loc = 'center right')
ax2.set_title("AGCE")



# CheckScore
CheckScore_ProjDF = np.array(Project_df.loc["CheckScore"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]])
CheckScore_ProjDF_std = np.array(Project_df.loc["CheckScore"][["comp_1_std", "comp_3_std", "comp_5_std", "comp_7_std", "comp_9_std", "comp_11_std", "comp_13_std"]])


CheckScore_CovSelect = np.array(CovSelect_df.loc["CheckScore"][["comp_1_mu", "comp_3_mu", "comp_5_mu", "comp_7_mu", "comp_9_mu", "comp_11_mu", "comp_13_mu"]])
CheckScore_CovSelect_std = np.array(CovSelect_df.loc["CheckScore"][["comp_1_std", "comp_3_std", "comp_5_std", "comp_7_std", "comp_9_std", "comp_11_std", "comp_13_std"]])



CheckScore_HNN = np.array([bench_df.loc["HNN_CheckScore_muSigma"][["CaliforniaHousing_mu"]][0]] * len(x))
CheckScore_HNN_std = np.array([bench_df.loc["HNN_CheckScore_muSigma"][["CaliforniaHousing_std"]][0]] * len(x))

CheckScore_MCDrop = np.array([bench_df.loc["MC_drop_CheckScore_muSigma"][["CaliforniaHousing_mu"]][0]] * len(x))
CheckScore_MCDrop_std = np.array([bench_df.loc["MC_drop_CheckScore_muSigma"][["CaliforniaHousing_std"]][0]] * len(x))

CheckScore_DeepEns = np.array([bench_df.loc["DeepEnsemble_CheckScore_muSigma"][["CaliforniaHousing_mu"]][0]] * len(x))
CheckScore_DeepEns_std = np.array([bench_df.loc["DeepEnsemble_CheckScore_muSigma"][["CaliforniaHousing_std"]][0]] * len(x))



ax3.plot(x, CheckScore_HNN, "--", label="HNN", c=clrs[0])
# ax3.fill_between(x, CheckScore_HNN - CheckScore_HNN_std,CheckScore_HNN+CheckScore_HNN_std ,alpha=0.3, facecolor=clrs[0])

ax3.plot(x, CheckScore_MCDrop, "--", label="MCDrop", c=clrs[1])
# ax3.fill_between(x, CheckScore_MCDrop - CheckScore_MCDrop_std,CheckScore_MCDrop+CheckScore_MCDrop_std ,alpha=0.3, facecolor=clrs[1])

ax3.plot(x, CheckScore_DeepEns, "--", label="DeepEns", c=clrs[2])
# ax3.fill_between(x, CheckScore_DeepEns - CheckScore_DeepEns_std,CheckScore_DeepEns+CheckScore_DeepEns_std ,alpha=0.3, facecolor=clrs[2])

ax3.plot(x, CheckScore_ProjDF, label="RandProj", c=clrs[3])
ax3.fill_between(x, CheckScore_ProjDF - CheckScore_ProjDF_std,CheckScore_ProjDF+CheckScore_ProjDF_std ,alpha=0.3, facecolor=clrs[3])

ax3.plot(x, CheckScore_CovSelect, label="CovSelect", c=clrs[4])
ax3.fill_between(x, CheckScore_CovSelect - CheckScore_CovSelect_std,CheckScore_CovSelect+CheckScore_CovSelect_std ,alpha=0.3, facecolor=clrs[4])


ax3.set_xlabel("Dimension")
ax3.set_ylabel("Loss")
ax3.legend(loc = 'center right', bbox_to_anchor=(1.5, 0.5))
ax3.set_title("CheckScore")
# Out:
# Text(0.5, 1.0, 'CheckScore')

# %%
np.array(MACE_ProjDF)
# Out:
# array([0.02288513, 0.0207662 , 0.02839684, 0.02044956, 0.02785688,
#        0.02624303, 0.01631069])
